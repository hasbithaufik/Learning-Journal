# %% [markdown]
# # Hasbi Thaufik Oktodila

# %% [markdown]
# # About This Notebook

# %% [markdown]
# Conducted in 28 Oct 2022.
#
# This is an attempt to explore text analysis. This project may be continued to Deep Learning and develop a model to detect cyber-violence from news headline.

# %% [markdown]
# # Data Loading

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')
#pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Loading the .csv file

# %%
df = pd.read_csv('cyber-operations-incidents.csv')
print(df.head(1).Sources_1)
# Out:
# 0    https://www.theregister.co.uk/2020/02/14/austr...
# Name: Sources_1, dtype: object

# %% [markdown]
# Exploring data's basic info

# %%
df.shape
# Out:
# (481, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 474 entries, 0 to 473
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          474 non-null    datetime64[ns]
#  1   Affiliations  341 non-null    object
#  2   Victims       446 non-null    object
#  3   Sponsor       434 non-null    object
#  4   Type          443 non-null    object
#  5   Category      452 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 25.9+ KB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dropping unused column

# %%
# dropping unused column

df = df.drop(['Title', 'Description', 'Response', 'Sources_1', 'Sources_2', 'Sources_3'], axis = 1)
df
# Out:
#           Date                                       Affiliations  \
# 0    2/13/2020                                              Turla
# 1    1/23/2020                                        Konni Group
# 2     4/6/2020                                                NaN
# 3    2/16/2020                                           APT-C-23
# 4    8/10/2020                                         Fox Kitten
# ..         ...                                                ...
# 476        NaN             Believed to be the work of MuddyWater.
# 477        NaN            Also known as Thallium and Smoke Screen
# 478        NaN                                                NaN
# 479        NaN  Believed to be responsible for the targeting o...
# 480        NaN                                             APT 28
#
#                                                Victims  \
# 0                            Austrian Foreign Ministry
# 1                     Employees of the U.S. government
# 2                                                  NaN
# 3                Israeli Defense Forces (IDF) soldiers
# 4             U.S. government agencies, U.S. companies
# ..                                                 ...
# 476  Russian Federation, Pakistan, Saudi Arabia, Tu...
# 477  France, Slovakia, Stanford University, U.S. Th...
# 478  Egypt, Israel, Saudi Arabia, United Arab Emira...
# 479                      United States, United Kingdom
# 480  Sixteen national and international sporting an...
#
#                                      Sponsor              Type  \
# 0                         Russian Federation         Espionage
# 1    Korea (Democratic People's Republic of)         Espionage
# 2                                  Australia  Data destruction
# 3                        Palestine, State of         Espionage
# 4                 Iran (Islamic Republic of)         Espionage
# ..                                       ...               ...
# 476               Iran (Islamic Republic of)         Espionage
# 477                                      NaN               NaN
# 478               Iran (Islamic Republic of)               NaN
# 479                       Russian Federation         Espionage
# 480                       Russian Federation         Espionage
#
#                        Category
# 0                    Government
# 1                    Government
# 2                Private sector
# 3                      Military
# 4    Government, Private sector
# ..                          ...
# 476  Government, Private sector
# 477  Government, Private sector
# 478  Private sector, Government
# 479              Private sector
# 480   Civil society, Government
#
# [481 rows x 6 columns]

# %% [markdown]
# ## Converting date's data type from 'object' to 'datetime'

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ## Removing null value on the date's column

# %%
df = df.dropna(axis=0, subset=['Date'])

# %% [markdown]
# ## Filling Null values in Affiliations to 'Uncategorized'

# %% [markdown]
# dalam mengisi null value di sisa kolom lain, ada beberapa hal yang dipertimbangkan
# - dalam kolom Affiliations, kolom ini akan diisi 'Uncategorized', karena masih ada informasi yang bisa diolah di baris-baris lainnya.
# - dalam kolom Victims, null akan diisi 'Uncategorized', karena null value disini akan dianggap tidak dapat dikategorisasikan.
# - Dalam kolom Sponsor, null value akan diisi 'Unknown'. Null value disini dianggap bahwa serangan cyber tersebut tidak diketahui sumbernya.
# - dalam kolom Type, kolom ini akan diisi 'Uncategorized', karena masih ada informasi yang bisa diolah di baris-baris lainnya.
# - Dalam kolom Category, kolom ini akan diisi 'Uncategorized', karena null value disini akan dianggap tidak dapat dikategorisasikan.

# %%
# Mengisi Affiliations dengan 'Uncategorized'
df['Affiliations'].fillna(value='Uncategorized', inplace=True)

# Mengisi Affiliations dengan 'Uncategorized'
df['Victims'].fillna(value='Uncategorized', inplace=True)

# Mengisi Sponsor dengan 'Unknown'
df['Sponsor'].fillna(value='Unknown', inplace=True)

# Mengisi Type dengan 'Uncategorized'
df['Type'].fillna(value='Uncategorized', inplace=True)

# Mengisi Category dengan 'Uncategorized'
df['Category'].fillna(value='Uncategorized', inplace=True)

# %%
df.head(1)
# Out:
#         Date Affiliations                    Victims             Sponsor  \
# 0 2020-02-13        Turla  Austrian Foreign Ministry  Russian Federation
#
#         Type    Category
# 0  Espionage  Government

# %% [markdown]
# # Data Exploration

# %%
dftype = df['Type'].value_counts().index
dftype
# Out:
# Index(['Espionage', 'Uncategorized', 'Sabotage', 'Denial of service',
#        'Data destruction', 'Financial Theft', 'Doxing', 'Defacement'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 9))
sns.countplot(data=df, x='Type', order=dftype)
ax.grid(axis='y', linewidth=0.5, alpha=0.25, color='blue')
ax.set(xlabel='Jenis Cyber Attack')
ax.set(ylabel='Jumlah')

plt.title('Jumlah Cyber Attack Berdasarkan Jenis', fontsize = 20, c='black')
plt.show()

# %%
df1 = df.groupby(['Victims'])['Date'].count().sort_values(ascending=False).to_frame().reset_index().head(15)
df1.rename(columns={"Date": "Total"})
df1['Victims']=='Banks of America, Citigroup, WellsFargor, US Bancorp, PNC, Capital One, Fifth Third Bank, BB&T, HSBC'
df1.loc[df1['Victims'].str.contains('HSBC'), 'Victims'] = 'Groups of Banks'
df1
# Out:
#                                      Victims  Date
# 0                              Uncategorized    28
# 1                              United States    21
# 2                                South Korea     7
# 3                                    Ukraine     7
# 4                                    Germany     6
# 5                                       NASA     4
# 6                                     Russia     4
# 7                                  Australia     3
# 8                                      India     3
# 9                   U.S. Department of State     3
# 10                U.S. Department of Defense     3
# 11                           Groups of Banks     2
# 12                               Switzerland     2
# 13                                      Iran     2
# 14  United States, United Kingdom, Hong Kong     2

# %%
ax = sns.barplot(x = 'Date', y='Victims', data=df1.sort_values(by='Date', ascending=False))
plt.xticks(rotation=90)
plt.figure(figsize=(15,8))
plt.tight_layout
plt.show()

# %%
# memastikan datatype dan nullvalue
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 474 entries, 0 to 473
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          474 non-null    datetime64[ns]
#  1   Affiliations  474 non-null    object
#  2   Victims       474 non-null    object
#  3   Sponsor       474 non-null    object
#  4   Type          474 non-null    object
#  5   Category      474 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 25.9+ KB

# %%
df.head(3)
# Out:
#         Date Affiliations                           Victims  \
# 0 2020-02-13        Turla         Austrian Foreign Ministry
# 1 2020-01-23  Konni Group  Employees of the U.S. government
# 2 2020-04-06          NaN                               NaN
#
#                                    Sponsor              Type        Category
# 0                       Russian Federation         Espionage      Government
# 1  Korea (Democratic People's Republic of)         Espionage      Government
# 2                                Australia  Data destruction  Private sector

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         481 non-null    object
#  1   Date          474 non-null    object
#  2   Affiliations  347 non-null    object
#  3   Description   481 non-null    object
#  4   Response      86 non-null     object
#  5   Victims       453 non-null    object
#  6   Sponsor       439 non-null    object
#  7   Type          447 non-null    object
#  8   Category      458 non-null    object
#  9   Sources_1     475 non-null    object
#  10  Sources_2     355 non-null    object
#  11  Sources_3     168 non-null    object
# dtypes: object(12)
# memory usage: 45.2+ KB

# %%
df['Victims'].unique()
# Out:
# array(['Austrian Foreign Ministry', 'Employees of the U.S. government',
#        nan, 'Israeli Defense Forces (IDF) soldiers',
#        'U.S. government agencies, U.S. companies',
#        'Saudi Arabian citizens in the Untied States',
#        'Global financial institutions',
#        'Iranian expats and dissidents, North American and Israeli organizations',
#        'Burisma', 'Ben Hubbard', 'Israel',
#        'Arabic speakers in Syria and surrounding region',
#        'Defense companies', 'Private companies in numerous countries',
#        'Poland’s War Studies University', 'Iranian expats and dissidents',
#        'Bapco',
#        'Vatican City, Pontifical Institute for Foreign Missions, Hong Kong Study Mission to China',
#        'Japanese, Russian, and South Korean civil society, private sector, and government entities.',
#        'Infrastructure used by foreign-based cybercriminals',
#        'Taiwanese government agencies and email accounts',
#        'The U.S. electrical grid', 'European aerospace and defense firms',
#        'U.S. government networks', 'Mitsubishi Electric employees',
#        'Tibetans',
#        'Private Companies, Governments, Nongovernmental Organizations, Individual Dissidents, Clergy, Democratic and Human Rights Activists',
#        'Japan, Russian Federation, Republic of Korea',
#        'COVID-19 Research Organizations',
#        'Taiwanese government agencies and officials’ email accounts',
#        'Mongolia',
#        'Air transportation and government agencies in Kuwait and Saudi Arabia',
#        'U.S. government and private companies', 'Jeff Bezos',
#        'World Health Organization (WHO)',
#        'Vatican networks, Vatican officials, Hong Kong Study Mission to China, Pontifical Institute for Foreign Missions (PIME)',
#        'Likely Armenian government officials', 'Central Asian Businesses',
#        'Argentina, Brazil, Bangladesh, Bosnia and Herzegovina, Bulgaria, Chile, Costa Rica, Ecuador, Ghana, India, Indonesia, Japan, Jordan, Kenya, Kuwait, Malaysia, Malta, Mexico, Mozambique, Nepal, Nicaragua, Nigeria, Parkistan, Panama, Peru, Philippines, Singapore, South Africa, South Korea, Spain, Taiwan, Tanzania, Togo, Turkey, Uganda, Uruguay, Vietnam, Zambia',
#        'Government of Mongolia', 'German critical infrastructure',
#        'Azerbaijani government networks',
#        'Government organizations and companies across the Middle East and Europe',
#        'Wuhan government, Chinese Ministry of Emergency Management',
#        'Websites and NATO-affiliated officials', 'India',
#        'Shahid Rajaee Port in Iran', 'U.S. defense contractors',
#        'Ukrainian citizens', 'Exim mail server users', 'U.S. government',
#        'U.S. government employees and possibly Westat employees',
#        'Latvia, Lithuania, Poland',
#        'Likely Indian government or civil society targets based on past targeting.',
#        'CPC Corporation',
#        'UN officials, including those affiliated with the UN Security Council',
#        'Japanese defense contractors',
#        'Australian government agencies and private companies',
#        'Universities in Hong Kong', 'Israeli water utilities',
#        'Government agencies, Private sector companies, Think tanks',
#        'Targets across sectors and throughout the world, but especially defense sector and the United Arab Emirates.',
#        'Organizations and individuals associated with U.S. politics',
#        'Cryptocurrency exchanges', 'Ukrainian government officials',
#        'Academics, researchers, and dissidents in the United States, Israel, Saudi Arabia, Europe, the UK, and possibly elsewhere.',
#        'Vietnamese government officials', 'UK Trade Minister',
#        'World Health Organization',
#        'Telecommunication providers in South Asia',
#        'Individuals associated with the U.S. election',
#        'Hong Kong citizens with iPhones',
#        'Malaysian government officials',
#        'Togolese opposition politicians, Togolese religious leaders',
#        'Multiple entities across the world.',
#        'Video game companies in Asia, including Taiwan and South Korea',
#        'Russia', 'Ukrainian national security targets',
#        'Google Play Store',
#        'North Koreans and North Korean–focused professionals',
#        'Central Asian and Eastern European ministries of foreign affairs and parliament',
#        'Individuals associated with the U.S. government or upcoming election',
#        'Noncritical devices in an Indian nuclear power plant',
#        'Democratic National Committee',
#        'United States, United Kingdom, Australia, Canada, Hong Kong, Switzerland',
#        'Hong Kong protesters', 'Bayer Pharmaceuticals', 'Tibet',
#        'Military, government, scientific organizations, and universities in the Middle East and across the world',
#        'Germany', 'Qatar, Turkey, Yemen',
#        'Governments and managed service providers in the U.S., Brazil, China, France, Germany, Italy, Mexico, Portugal, Spain, and the United Kingdom',
#        'Global telecommunications companies', 'Tibetans , Uighurs',
#        'Avast',
#        'Numerous Kazakh government officials and private individuals and some Chinese individuals',
#        'Center for Strategic and International Studies, German Council on Foreign Relations, The Aspen Institutes in Europe, The German Marshall Fund',
#        'French Ministry for Europe and European Affairs, Ministry of Foreign and European Affairs of the Slovak Republic, Stanford University, Sina, Foreign ministry of the South African government',
#        'Millions of individuals in the UAE and globally',
#        'Iranian rocket and missile launch systems',
#        'Foreign Ministry of the Czech Republic',
#        'Georgian government, courts, nongovernmental organizations, media, and businesses',
#        'United States', 'Visma', 'Unnamed U.S.-based entities',
#        'Industrial control systems manufacturers, suppliers, and maintainers',
#        'Yandex', 'Japanese organizations',
#        'Oil companies in the Middle East', 'U.S. private sector',
#        'Cambodian government',
#        'United States, France, Japan, Singapore, United Kingdom, Hong Kong',
#        'University of Hawaii, University of Washington, Massachusetts Institute of Technology , Pennsylvania State University, Duke University',
#        'An unnamed U.S. presidential campaign',
#        'National Association of Manufacturers', 'U.S. government,',
#        'Bahrain', 'Singapore, Russia, United Kingdom',
#        'Indian Space Research Organization',
#        'Japanese organizations with subsidiaries in China',
#        'A U.S. presidential campaign, government officials, journalists, and prominent expatriate Iranians',
#        'Hong Kong', 'Ukrainian government entities', 'Indonesia',
#        'Airbus',
#        'Egyptian journalists, academics, lawyers, opposition politicians, and human rights activists',
#        'South Korean macOS users',
#        'Russian speakers, as well as diplomatic and government institutions in Eastern Europe',
#        'China', 'BMW and Hyundai',
#        'Belgium, Luxembourg, The Philippines, and Vietnam',
#        'Uzbek activists and dissidents',
#        'Saudi Arabian dissidents, , Foreign journalists',
#        'Telecom companies in Africa, Europe, and Southeast Asia',
#        'Amnesty International Hong Kong', 'Iran',
#        'Maati Monjib, an academic and activist, and Abdessadak El Bouchattaoui, a human rights lawyer',
#        'United States, South Korea, Canada, Lebanon , United Arab Emirates',
#        'British Post Office and local government networks',
#        'Ministries of foreign affairs of three European countries and an EU country embassy in the United States',
#        'Russian Federation', 'Uighurs',
#        'Federation Internationale de Football Association (FIFA)',
#        'Pakistan, Afghanistan, India, Iraq, United Arab Emirates, United States, Australia, Germany',
#        'Marriott International Inc', 'Republic of Korea',
#        'Australia, Canada, China, Israel, Japan, Switzerland, Turkey, United Kingdom, United States',
#        'Islamic State Group', 'Westinghouse Electric Company',
#        'South Korea', 'Ukraine', 'Republic of Korea, Japan, Vietnam',
#        'Omar Abdulaziz',
#        'Worldwide, United States, United Kingdom, Ukraine',
#        'United States, Spain, Russian Federation, United Kingdom',
#        'Australia', 'Candidates for the U.S. Congress',
#        'United States, United Nations, UNICEF, Australia, Canada, China, Denmark, Germany, Ireland, Israel, Italy, Japan, Malaysia, Netherlands, Norway, Poland, Singapore, Republic of Korea, Spain, Sweden, Switzerland, Turkey, United Kingdom',
#        'Singapore, Cambodia', 'Yahya Assiri', 'SingHealth',
#        'South Korea, Japan', 'United States, Kenya, Mongolia, Brazil',
#        'Saudi Arabia, Egypt, Turkey, Iraq, Spain, Norway, Australia, South Korea',
#        'Palestine, Egypt, Jordan, United Arab Emirates, Saudi Arabia, Djibouti, Qatar, Chile, Lebonon, Somalia, Iraq, Morocco, Syria, India, Iran, Canada, United States, United Kingdom, Germany, Israel, Afghanistan, Serbia, Russia, Oman, Kuwait, South Korea, Denmark',
#        'United States, United Kingdom, India, Thailand, Guatemala, Germany, France, Canada, Brazil, China, Bangladesh, Thailand, Hong Kong, Japan, Australia,',
#        'Aerospace companies based in Arizona, Massachusetts, and Oregon',
#        'South Africa, Kenya, United Kingdom, Malaysia, Suriname, Turkey, Turkmenistan, Ukraine, Romania, Portugal, Afghanistan',
#        'Japan',
#        'United States, United Kingdom, Japan, South Korea, China, Hong Kong, Universities in Hong Kong',
#        'Iraq, Pakistan, Israel, United Kingdom',
#        'United States, Mexico, Chile, Brazil, Uruguay, Poland, Turkey, Bangladesh, Malaysia, Vietnam, Russia, Phillipines, Taiwan',
#        'Networks and clients of Hewlett Packard Enterprise, IBM, Fujitsu, Tata Consultancy Services, NTT Data, Dimension Data, Computer Sciences Corporation, and DXC Technology',
#        'European Ice Hockey Federation, International Ski Federation, International Biathlon Union, International Bobsleigh and Skeleton Federation, International Luge Federation',
#        'AMC Theatres',
#        'European Union, United Nations, American Federation of Labor and Congress of Industrial Organizations',
#        'Cambodia', 'Organization for the Prohibition of Chemical Weapons',
#        'Austal Ltd', 'Mammoth Screen', 'Saipem',
#        'U.S. Anti-Doping Agency', 'Turkey,',
#        'United States, Canada, Germany, Lebanon, France', 'Qatar',
#        'Court of Arbitration for Sport', 'Mexican journalists',
#        'United States, Canada, Australia, Japan, China, Republic of Korea, Taiwan, Thailand, Russia, India, Israel, Iran',
#        'Russia, France, The Netherlands, Switzerland, Germany, Ukraine',
#        'Canadian Centre for Ethics in Sport', 'Bellingcat',
#        'FedEx, UK National Health Service, Telefonica, Deutsche Bahn, PetroChina, Hitachi, Renault, Nissan, Sberbank',
#        'United States, Saudi Arabia, South Korea', 'Ethiopian dissidents',
#        'Switzerland', 'Cryptocurrency exchanges in South Korea',
#        'Ukraine, Japan, Russia, Bulgaria, Turkey',
#        'Saudi Arabia, Iraq, United Arab Emirates, Georgia, Israel, Pakistan, Turkey, India, United States',
#        'International Association of Athletics Federations', 'Panama',
#        'Far Eastern International Bank', 'Islam Channel',
#        'United States, The Philippines, Asia Pacific Economic Cooperation, Hong Kong, Malaysia',
#        'Rosneft, WPP Plc., Maersk, Cie de Saint-Gobain, SNCF, Merck, Mondelez, Port of Rosario, Kyivenergo, The government of Ukraine',
#        'Ethnic minorities in China',
#        'Japan, Korea (Republic of), Russian Federation, China, Mitsubishi Group',
#        "Moody's Analytics, Siemens, Trimble",
#        'Japan, United States, United Kingdom, India, Canada, Brazil, South Africa, Australia, Thailand, South Korea, France, Switzerland, Sweden, Finland, Norway, New Zealand',
#        'Kaspersky Labs',
#        'South Asian telecommunication providers, Middle Eastern government, aviation, education, and investment organizations',
#        'Belarus', 'UK Parliament',
#        'Israel, Saudi Arabia, United States, Jordan, Germany',
#        'Czech Republic',
#        'Argentina, Brazil, Peru, Ecuador, Brunei, Malaysia',
#        'Qatar News Agency', 'Norway', 'Israel Defense Force',
#        'Aristegui Noticias, Carlos Loret de Mola, Mexicans against Corruption and Impunity, Centro PRODH, Mexican Institute for Competitiveness',
#        'North Korea', 'Montenegro', 'Ministry of Defense',
#        'The 2016 presidential campaign of Marco Rubio', 'Global',
#        'Denmark', "Emmanuel Macron's 2017 presidential election campaign",
#        'Saudi Arabia',
#        'United States, United Kingdom, Uzbekistan, South Korea', 'Italy',
#        'Ukraine, Russia, Saudi Arabia, Austria',
#        'United States, European Union',
#        'South Korea, Sony Pictures Entertainment , United States, Bangladesh Bank, Defense companies in Israel and the Middle East, Global banks, U.S. defense contractors',
#        'General Authority of Civil Aviation of Saudi Arabia',
#        'Bangladesh Central Bank, Tien Phong Bank, Banco Del Austro, Poland',
#        'Sweden', 'United Arab Emirates, United Kingdom',
#        'Democratic National Committee, Democratic Congressional Campaign Committee',
#        'Israel, Turkey, Qatar, Kuwait, Saudi Arabia, Lebanon, United States',
#        'The Islamic State Group', 'Ukrenergo', 'World Anti-Doping Agency',
#        'China, Taiwan, South Korea, United States, Russia', 'Yahoo',
#        'Council on Foreign Relations, Brookings Institution',
#        'China, Hong Kong, Taiwan, Myanmar',
#        'Israel, United States, Denmark, Iran, United Kingdom, Canada, France, Germany, Russia, China, Syria, Saudi Arabia, Sweden, Italy, Bahrain',
#        'Myanmar',
#        'Myanmar, Canada, United States, Germany, India, South Korea, Singapore',
#        'Ministry of Foreign Affairs, Iran,',
#        'Russia, Belgium, Sweden, Iran, China, Rwanda', 'Philippines',
#        'Egypt, Israel', 'Ukraine Armed Forces', 'Japan, Taiwan',
#        'Kazakh dissidents', 'Bundestag',
#        'Prikarpattiaoblenergo Electric Company',
#        'India, Thailand, South Korea, Saudi Arabia, Malaysia, United States, Vietnam, Cambodia, Indonesia, Myanmar, China, Laos, Singapore, Phillipines',
#        'Anthem',
#        'China, United States, Philippines, Germany, Vietnam, Association of Southeast Asian Nations, Cambodia, Laos',
#        'Vietnam',
#        'Saudi Arabia, United Arab Emirates, Israel, Jordan, Turkey',
#        'United States, United Kingdom, Hong Kong',
#        'United States, United Kingdom, France', 'TV5 Monde', 'Thailand',
#        'Uganda',
#        'Saudi Arabia, Israel, Yemen, Venezuela, Iraq, United Kingdom, Afghanistan, Kuwait, Egypt, United Arab Emirates, Turkey, Syria, Iran, Canada, Jordan',
#        'Bureau of Meteorology', 'Japan Pension Service',
#        'Iran, Russia, Pakistan, Afghanistan, India, China, Syria, Mali, Lebanon, Yemen, Algeria, United Arab Emirates, Kenya, United Kingdom, Libya',
#        'Pentagon', 'Office of Personnel Management',
#        'Malaysia, Philippines, India, Indonesia, United States',
#        'Joint Chiefs of Staff', 'United Airlines', 'Seoul Subway System',
#        'GitHub', 'Permanent Court of Arbitration',
#        'White House, U.S Department of State',
#        'Members of the National Assembly', 'Dutch Safety Board',
#        'Ministry of Foreign Affairs, Ministry of the Interior, Ministry of Defense',
#        'U.S. Department of State',
#        'Japan, Hong Kong, Taiwan, Philippines, Indonesia, Vietnam',
#        'Community Health Systems',
#        'United States, Spain, Japan, Germany, France, Italy, Turkey, Ireland, Poland, China, Russia, Ukraine, United Kingdom, Greece',
#        'Japan, Taiwan, Russia',
#        'Contractors of U.S. Transportation Command',
#        'France, Russia, Belarus, Romania, United States, Netherlands, Kazakhstan, Saudi Arabia, Iran, Poland, Germany, Uzbekistan, Tajikistan, India, Iraq, Austria, Armenia',
#        'Sony Pictures Entertainment',
#        'United States, United Kingdom, Germany, Netherlands, Belgium, Switzerland, Italy, Russia, China, Japan, Indonesia',
#        'Georgia, NATO, OSCE, France, Ukraine, United Kingdom, Jordan, Belgium, Germany, United States, Pakistan, Poland, Hungary, Asia Pacific Economic Cooperation, European Commission, World Anti-Doping Agency, International Association of Athletics Federations, Afghanistan, Armenia, Turkey, Kazakhstan, Tajikistan, Mongolia, China, Japan, Canada, Organization for the Prohibition of Chemical Weapons, Court of Arbitration for Sport, Federation Internationale de Football Association, Burisma, Organizations and individuals associated with U.S. politics, Azerbaijani government networks, Unnamed U.S. federal agency',
#        'Russia, Ukraine, Poland, Lithuania, Belarus, Azerbaijan, Kyrgyzstan, Kazakhstan, Iran, Israel, Georgia',
#        'Japan, Taiwan, China, Russia, South Korea, World Health Organization, North Korea',
#        'U.S. government/defense sector websites, Israel, United Kingdom, Saudi Arabia, Iraq, Individuals associated with the U.S. government or 2020 presidential election',
#        'Canada, China, United Kingdom, France, Germany, India, Israel, United States, Kuwait, Mexico, Pakistan, Qatar, Saudi Arabia, South Korea, Turkey',
#        'Russia, Kazakhstan, Belarus, India, Czech Republic',
#        'Las Vegas Sands Corporation',
#        'Westinghouse, Solar World, U.S. Steel, ATI, USW, Alcoa',
#        'Unnamed German steel mill',
#        'Venezuela, Ecuador, Colombia, Russia, Brazil, Peru, Cuba, Spain, Sweden, China, Germany, United States, Belgium, France, Malaysia',
#        'National Research Council', 'USIS',
#        'Morocco, Brazil, United Kingdom, France, Spain, Switzerland, Libya, United States, Iran, Venezuela, South Africa, Germany, Poland, Tunisia',
#        'Pro-democracy occupy central activists',
#        'Syria, Iran, Malaysia, United States, China, Turkey, Netherlands, Germany, United Kingdom, Russia, Algeria, Ivory Coast, Spain, Norway, Greece',
#        'Apple iCloud in China',
#        'United States, Iranian internet activists', 'U.S. Postal Service',
#        'Algeria, Afghanistan, Belgium, Brazil, Fiji, Germany, Iran, India, Indonesia, Kiribati, Malaysia, Pakistan, Syria, Russia',
#        'U.S. satellite and aerospace sector',
#        'National Oceanic and Atmospheric Agency',
#        'Bangladesh, Sri Lanka, Pakistan', 'Ministry for Foreign Affairs',
#        'Ministry of Unification, Sejong Institute, Korea Institute for Defense Analyses, UN officials, including those affiliated with the UN Security Council',
#        'Hong Kong, United States',
#        'European Union, India, United Kingdom',
#        'United States, Georgia, Brazil, China, Japan, Mexico, New Zealand, South Korea, Turkey, Ukraine, Belgium, Portugal, Romania, Kazakhstan, India',
#        'U.S. Navy',
#        'Mongolia, India, Russia, Kazakhstan, Kyrgyzstan, China, Tajikstan, South Korea, Spain, Germany, United States, Canada, United Kingdom, Chile, Morocco',
#        'South Korea, Japan, China, United States, Germany',
#        'Russia, Kazakhstan, Azerbaijan, Belgium, India, Afghanistan, Armenia, Iran, Turkmenistan, Ukraine, United States, Vietnam, Belarus, Greece, Italy',
#        'European Aeronautic Defense and Space Company (EADS), ThyssenKrupp',
#        'United States, United Kingdom, Switzerland, Taiwan, Singapore, Canada, Israel, India, France, Norway, Belgium, Luxembourg, United Arab Emirates, South Africa, Japan',
#        'Indian Defense Research Organization, Defense Research and Development Lab',
#        'Hungary, Belarus',
#        'United States, Germany, Sweden, United Kingdom, Australia',
#        'Australian Security Intelligence Organization, Department of the Prime Minister and Cabinet, Department of Defense, Department of Foreign Affairs, and Trade',
#        'Saudia Arabia Aramco Company',
#        'Iran, Israel, Palestine, Sudan, Syria, Lebanon, Saudi Arabia, Egypt, Hungary, Austria, Russia, United Arab Emirates, France',
#        'Iran, Israel, United States, Pakistan', 'Nortel Networks',
#        'Lebanon, Palestine, Israel, United States, Iran, United Arab Emirates, Qatar, Jordan, Germany , Egypt',
#        'BBC Persian TV',
#        'United States, Hong Kong, Taiwan, Canada, Australia, China, United Kingdom, India, Denmark, Switzerland',
#        'India, United States, United Kingdom, Spain, France',
#        'Bank of America, Citigroup, Wells Fargo, US Bancorp, PNC, Capital One, Fifth Third Bank, BB&T, HSBC',
#        'Coca-Cola', 'India, Japan',
#        'Syrian Dissidents, Humanitarian Groups, Western Media Outlets, Associated Press, U.S. government websites, Twitter, PayPal, eBay',
#        'U.S. Chamber of Commerce', 'South Korea, U.S. Forces Korea',
#        'National Agricultural Cooperative Federation',
#        'Oak Ridge National Laboratory',
#        'United States, Canada, South Korea, Taiwan, Japan, Switzerland, United Kingdom, Indonesia, Vietnam, Singapore, Hong Kong, Germany, India, United Nations, International Olympic Committee',
#        'Democratic Progressive Party', 'DigiNotar',
#        'Mitsubishi Heavy Industries',
#        'United States, Bangladesh, United Kingdom, Argentina, Singapore, China, Taiwan, Germany, Czech Republic, Hong Kong, India, Netherlands, Finland, South Korea, France',
#        'Iran, Sudan', 'NASA',
#        'Treasury Board of Canada, Department of Finance, Defense Research and Development Canada',
#        'RSA',
#        'Google, Adobe, Juniper Networks, Rackspace, Yahoo, Symantec, Northtrop Grumman, Morgan Stanley, Dow Chemical',
#        'Baidu', "Prime Minister's Office",
#        'Vietnamese political activists',
#        'Marathon Oil, ExxonMobil, ConocoPhillips',
#        'Rio Tinto, BHP Billiton, Fortescue Metals',
#        'National Security Council, Ministry of External Affairs, Institute for Defence Studies and Analyses, United Nations',
#        'Iran, Indonesia, India, Azerbaijan, Pakistan, Malaysia, United States, Uzbekistan, Russia, United Kingdom, South Korea, Taiwan',
#        'Office of Senator Ben Nelson', 'U.S. Department of Defense',
#        'South Korea, United States',
#        'Iran, Bangladesh, India, South Korea, Germany, Pakistan, Taiwan, Thailand, Indonesia, Philippines, Latvia, Portugal, Barbados, China',
#        'Georgia',
#        'Tibet Support Network, Human Rights in China, Students For a Free Tibet',
#        'Ministry of External Affairs, India National Informatics Centre',
#        'Obama Campaign, McCain Campaign',
#        'United States, Russia, Spain, Italy, Kazakhstan, Germany, Poland, Latvia, Lithuania, United Kingdom, Ukraine',
#        'Estonia', 'U.S. Department of Homeland Security',
#        'Syrian Arab Air Force',
#        'China Aerospace Science & Industry Corporation, National Defense Research Institutes, Military Industrial Labs, Ministry of Foreign Affairs',
#        'Oak Ridge National Laboratory, Los Alamos National Laboratory, Lawrence Livermore National Laboratory, U.S. Department of Energy, National Nuclear Security Administration',
#        'National Defense University',
#        'German Chancellery, Ministry of Foreign Affairs, Ministry for Economic Affairs and Energy, Ministry of Education and Research',
#        'French Defence Ministry', 'Australia, New Zealand',
#        'Naval War College',
#        'U.S. Department of State, U.S. Department of Defense, U.S. Department of Energy, U.S. Department of Homeland Security, NASA, UK Ministry of Defense, UK House of Commons, UK Foreign Office',
#        'Israel Defense Forces',
#        'Russian Federation, Pakistan, Saudi Arabia, Turkey, North America',
#        'France, Slovakia, Stanford University, U.S. Think Tanks, UK Think Tanks',
#        'Egypt, Israel, Saudi Arabia, United Arab Emirates, Bahrain, Iran, Azerbaijan, Afghanistan',
#        'United States, United Kingdom',
#        'Sixteen national and international sporting and anti-doping organizations across three continents'],
#       dtype=object)

# %%
df.head(1)
# Out:
#                                  Title       Date Affiliations  \
# 0  Attack on Austrian foreign ministry  2/13/2020        Turla
#
#                                          Description  \
# 0  The suspected Russian hackers conducted a week...
#
#                                             Response  \
# 0  Confirmation   https://www.theregister.co.uk/2...
#
#                      Victims             Sponsor       Type    Category  \
# 0  Austrian Foreign Ministry  Russian Federation  Espionage  Government
#
#                                            Sources_1  \
# 0  https://www.theregister.co.uk/2020/02/14/austr...
#
#                                            Sources_2 Sources_3
# 0  https://www.bmeia.gv.at/en/the-ministry/press/...       NaN

# %%
df.Victims.value_counts().to_frame().head(10)
# Out:
#                             Victims
# United States                    21
# South Korea                       7
# Ukraine                           7
# Germany                           6
# NASA                              4
# Russia                            4
# U.S. Department of Defense        3
# Australia                         3
# U.S. Department of State          3
# India                             3

# %%
df.Category.value_counts().to_frame().head(10)
# Out:
#                                            Category
# Private sector                                  128
# Government                                      104
# Government, Private sector                       55
# Civil society                                    52
# Military                                         21
# Government, Military                             17
# Government, Civil society                        15
# Private sector, Government                       14
# Government, Private sector, Civil society        12
# Military, Government                              8

# %%
df.Type.value_counts().to_frame().head(10)
# Out:
#                    Type
# Espionage           374
# Sabotage             23
# Denial of service    18
# Data destruction     14
# Financial Theft       7
# Doxing                6
# Defacement            5

# %%
df_esp_gov = df[(df['Type'] == 'Espionage') & (df['Category'] == 'Government')]
df_esp_gov.info
# Out:
# <bound method DataFrame.info of                                                  Title        Date  \
# 0                  Attack on Austrian foreign ministry   2/13/2020
# 1    Spear-phishing campaign against unnamed U.S. g...   1/23/2020
# 21                                           BlackTech   8/19/2020
# 24        Targeting of U.S. government agency networks  11/14/2020
# 30   Targeting of Taiwanese government agencies and...   8/19/2020
# ..                                                 ...         ...
# 457            Compromise at NASA Kennedy Space Center  11/19/2008
# 458       Compromise of NASA network in Washington, DC  11/19/2008
# 467           Compromise of German government networks   8/27/2007
# 469  Attempted compromise of Australian and New Zea...   9/12/2007
# 470                 Compromise at the State Department   7/11/2006
#
#                                           Affiliations  \
# 0                                                Turla
# 1                                          Konni Group
# 21                                                 NaN
# 24   Believed to be the work of the Chinese governm...
# 30                                           BlackTech
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 467                                                NaN
# 469                                                NaN
# 470                                                NaN
#
#                                            Description  \
# 0    The suspected Russian hackers conducted a week...
# 1    The suspected North Korean threat actor Konni ...
# 21   Responsible for targeting governments in Asia,...
# 24   Chinese hackers scanned networks in search of ...
# 30   Hackers exploited vulnerabilities in at least ...
# ..                                                 ...
# 457  Malware gathered data from computer networks a...
# 458  Spear phishing compromised computers at NASA h...
# 467  Threat actors compromised computers in the cha...
# 469  An attempted compromise of government computer...
# 470  Threat actors exfiltrated sensitive but unclas...
#
#                                               Response  \
# 0    Confirmation   https://www.theregister.co.uk/2...
# 1                                                  NaN
# 21                                                 NaN
# 24   Confirmation   https://us-cert.cisa.gov/ncas/a...
# 30   Confirmation   https://www.reuters.com/article...
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 467  Denouncement   http://www.spiegel.de/internati...
# 469                                                NaN
# 470                                                NaN
#
#                                                Victims  \
# 0                            Austrian Foreign Ministry
# 1                     Employees of the U.S. government
# 21    Taiwanese government agencies and email accounts
# 24                            U.S. government networks
# 30   Taiwanese government agencies and officials’ e...
# ..                                                 ...
# 457                                               NASA
# 458                                               NASA
# 467  German Chancellery, Ministry of Foreign Affair...
# 469                             Australia, New Zealand
# 470                           U.S. Department of State
#
#                                      Sponsor       Type    Category  \
# 0                         Russian Federation  Espionage  Government
# 1    Korea (Democratic People's Republic of)  Espionage  Government
# 21                                     China  Espionage  Government
# 24                                     China  Espionage  Government
# 30                                     China  Espionage  Government
# ..                                       ...        ...         ...
# 457                                    China  Espionage  Government
# 458                                    China  Espionage  Government
# 467                                    China  Espionage  Government
# 469                                    China  Espionage  Government
# 470                                    China  Espionage  Government
#
#                                              Sources_1  \
# 0    https://www.theregister.co.uk/2020/02/14/austr...
# 1    https://unit42.paloaltonetworks.com/the-fractu...
# 21   https://www.reuters.com/article/us-taiwan-cybe...
# 24      https://us-cert.cisa.gov/ncas/alerts/aa20-258a
# 30   https://www.reuters.com/article/us-taiwan-cybe...
# ..                                                 ...
# 457  http://www.bloomberg.com/bw/stories/2008-11-19...
# 458  http://www.bloomberg.com/bw/stories/2008-11-19...
# 467  http://www.spiegel.de/international/world/espi...
# 469  https://wikileaks.org/gifiles/docs/35/355203_-...
# 470  http://www.cbsnews.com/news/state-department-c...
#
#                                              Sources_2  \
# 0    https://www.bmeia.gv.at/en/the-ministry/press/...
# 1                                                  NaN
# 21   https://malpedia.caad.fkie.fraunhofer.de/actor...
# 24                                                 NaN
# 30   https://www.scmp.com/news/china/diplomacy/arti...
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 467                                                NaN
# 469  http://www.spamfighter.com/News-9096-Foreign-H...
# 470                                                NaN
#
#                                              Sources_3
# 0                                                  NaN
# 1                                                  NaN
# 21                                                 NaN
# 24                                                 NaN
# 30                                                 NaN
# ..                                                 ...
# 457                                                NaN
# 458                                                NaN
# 467                                                NaN
# 469  https://web.archive.org/web/20071013131220/htt...
# 470                                                NaN
#
# [89 rows x 12 columns]>

# %%
df_esp_gov.shape
# Out:
# (89, 12)

# %%
df_esp_gov2 = df[(df['Type'] == 'Espionage') & (df['Victims'] == 'United States')]
df_esp_gov2.count()
# Out:
# Title           20
# Date            20
# Affiliations    14
# Description     20
# Response         3
# Victims         20
# Sponsor         16
# Type            20
# Category        19
# Sources_1       20
# Sources_2       13
# Sources_3        5
# dtype: int64
